# %% [markdown]
# ## 1. 为什么学习Python数据分析

# %% [markdown]
# - 好学: 语法简单，调试/运行方便(jupyter notebook)
# - 好用: 数据分析，及相关领域（科学计算，数据挖掘，爬虫，机器学习……）都有可调用的包
# - 好查: 百度/google

# %% [markdown]
# ## 2. Python环境安装
# 循序渐进: 简单程序jupyter->复杂工程IDE->虚拟环境/docker....

# %% [markdown]
# ### 2.1 jupyter安装
# - 百度搜索 "Anaconda"，下载对应自己电脑版本的安装包，安装
#     - if Mac: 打开terminal，命令行中输入"jupyter notebook"，回车
#     - if Windows: win+S搜索“Anaconda prompt”，输入"jupyter notebook"，回车
#     ![image.png](attachment:image.png)
# - 关闭jupyter: 在命令行界面中ctrl+c

# %% [markdown]
# ### 2.2 IDE安装
# - Pycharm，sublimeText，vscode
#
# #### 使用IDE的目的
# - 源代码查看
# - 代码跳转
# - 打断点调试
# - 辅助插件

# %% [markdown]
# ### 2.3 虚拟环境
# - 依赖冲突
# - 部署效率

# %% [markdown]
# ## 3. 学习内容与心得

# %% [markdown]
# **学习内容**
# - python基础语法
# - python数据结构
# - pandas处理表格数据
# - python可视化
# - python科学计算
# - 后续学习内容展望

# %% [markdown]
# ** 学习心得 **
# - jupyter notebook: 快速尝试，掌握新知识点
# - 工作/kaggle比赛: 通过实际应用积累经验，增强信心
# - 百度/google: 学会总结自己的问题，选择关键词
# - 应用第一: api随用随查，不要背，不要一上来就扎进源码
